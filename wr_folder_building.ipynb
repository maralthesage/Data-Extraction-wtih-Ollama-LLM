# %% [markdown]
# ## Creating folders for each WARENGRUPPE along with the product data for that WR
#
# This is a one-time used code to structure the data so that products for each product group are in their separate folder along with their prompt format and allowed keys as well as their output csv and json files. This will structure the data so that each product group is treated individually based on its attributes.

# %%
## Importing libraries and initializing values class to import the relevant variables
import pandas as pd
from values import *
import os

val = Values()

# %%
## loading data from warengruppe list, the products in the webshop and the marketing artikel list that connects the other two datas together
warengr = pd.read_csv(val.wr_filepath,delimiter=';',encoding='latin-1')
shop = pd.read_excel(val.shop_file_path)

## We need the first part of the StoreId number to connect with the marketing artikel list
shop['NUMMER'] = shop['StoreId'].str.split().str[0]
marketing_art = pd.read_csv(val.marketing_artikel,delimiter=';',encoding='latin-1')
# Out:
# /var/folders/5j/sk834jzs3cg8kh3yp7743_ym0000gp/T/ipykernel_53051/2847459912.py:7: DtypeWarning: Columns (0,2,3,14,16,18,22,24,25,26,28,29,30,60,61,62,63,64,65,71,75,76,97,99,100,111,113,115,119,121,122,123,125,126,127,157,158,159,160,161,162,168,172,173) have mixed types. Specify dtype option on import or set low_memory=False.
#   marketing_art = pd.read_csv(val.marketing_artikel,delimiter=';',encoding='latin-1')

# %% [markdown]
# ### Data Processing

# %%
## changing data types to numeric in marketing artikel list
marketing_art['WARENGR'] = pd.to_numeric(marketing_art['WARENGR'],errors='coerce')
marketing_art.dropna(subset=['WARENGR','NUMMER'],inplace=True)
marketing_art['WARENGR'] = marketing_art['WARENGR'].astype(int)

## cleaning marketing artikel list
marketing_art = marketing_art[marketing_art['WM'].isna()]
marketing_art = marketing_art.dropna(subset='WARENGR')
marketing_art = marketing_art[['WM','NUMMER',"MA_NUMMER",'WARENGR']]
marketing_art = marketing_art.drop_duplicates(subset=['NUMMER'])
marketing_art['NUMMER'] = marketing_art['NUMMER'].str.strip()

## cleaning warengruppe items in warengr list
warengr = warengr[warengr['WAREN_GRP'].str.contains('x',case=False) == False]
warengr['WAREN_GRP'] = pd.to_numeric(warengr['WAREN_GRP'],errors='coerce')
warengr.dropna(subset='WAREN_GRP',inplace=True)
warengr['WAREN_GRP'] = warengr['WAREN_GRP'].astype(int)
warengr = warengr[(warengr['WAREN_GRP'].isna() == False) & (warengr['WAREN_GRP'] != 'nan')]

# %% [markdown]
# ### Data Structure Creation

# %%
wg_data = []
for num, val in zip(warengr['WAREN_GRP'],warengr['WAREN_GRNA']):
    ## iterating over warengruppe
    artikels_in_wr = marketing_art[marketing_art['WARENGR'] == num]
    ## connecting marketing artikels for each warnegruppe with the shop list
    artikels = pd.merge(artikels_in_wr,shop,how='inner',on="NUMMER")
    artikels = artikels.dropna(subset='WARENGR')
    ## selecting necessary columns
    artikels = artikels[['WM','NUMMER','WARENGR','Name','Beschreibung']]
    ## renaming columns 
    artikels = artikels.rename(columns={'Name':'NAME','Beschreibung':'BESCHREIBUNG'})
    ## data cleaning (removing html codes and unnecessary characters)
    artikels['BESCHREIBUNG'] = artikels['BESCHREIBUNG'].str.replace(' ',' ',regex=True)
    artikels['BESCHREIBUNG'] = artikels['BESCHREIBUNG'].str.replace(r'(<[^>]*>)',' ',regex=True,case=False)
    artikels['BESCHREIBUNG'] = artikels['BESCHREIBUNG'].str.replace(r'&nbsp_|&nbsp;',' ',regex=True)
    artikels['BESCHREIBUNG'] =artikels['BESCHREIBUNG'].str.replace('&Oslash',' ')
    artikels = artikels[artikels['BESCHREIBUNG'].isna() == False]
    ## preparing the product description to have all the information by concatenating both names and description together
    artikels['BESCHREIBUNG'] = artikels['NAME'] + ' - ' + artikels['BESCHREIBUNG']
    artikels = artikels[artikels['WARENGR'].isna() == False]
    artikels = artikels.drop_duplicates()
    wg_data.append([num,val,len(artikels)])

    # if len(artikels) != 0:
    #     path = os.path.join(val.parent_dir, str(num))
    #     print(str(num) + ' ' + str(len(artikels)))
    #     print(path)
        ## Building folders based on the warengruppe numbers
        # os.mkdir(path) 

        # ## inserting the csv file of the products for each warengruppe and adding a prompt placeholder text (to be filled)
        # with open(f'{path}/prompt_{num}.txt','w') as txt:
        #     txt.write("prompt-to-be-filled")
        # artikels.to_csv(f'{path}/{num}.csv',encoding='utf-8', sep=';',index=False)
wg_data
# Out:
# [[360, 'zz Terrinen&Timbales&Pasteten', 0],
#  [430, 'zz Bestecke', 0],
#  [270, 'zz Haushaltsgeräte', 0],
#  [820, 'zz Bar & Weinkeller', 0],
#  [440, 'zz Glaswaren', 0],
#  [350, 'zz Ofenzubehör', 0],
#  [460, 'zz Bar Accessoires', 0],
#  [900, 'zz Marketing', 0],
#  [610, 'zz Transportieren', 0],
#  [1400, 'Outdoor', 5],
#  [830, 'zz Wohnen & Dekoration', 0],
#  [250, 'zz Kaffee&Espresso&Tee', 0],
#  [450, 'zz Servieren', 0],
#  [922, 'zz Geschenkverpackung', 0],
#  [230, 'zz Kochen&Braten&Frittieren', 0],
#  [420, 'zz Geschirr', 0],
#  [590, 'zz Spezialitäten', 0],
#  [130, 'zz Dessertzubereitung', 0],
#  [571, 'zz Fleisch', 0],
#  [220, 'zz Elektro-Kleingeräte', 0],
#  [700, 'zz Terrasse & Garten', 0],
#  [620, 'zz Ordnung & Aufbewahren', 0],
#  [840, 'zz Lampen & Leuchten', 0],
#  [260, 'zz Toaster-&Frühstückselektro', 0],
#  [470, 'zz Küchentextilien', 0],
#  [110, 'zz Backformen und -zubehör', 0],
#  [370, 'zz Pizza & Pasta', 0],
#  [480, 'zz Saisondekoration', 0],
#  [630, 'zz Säubern & Pflegen', 0],
#  [921, 'zz Geschenkgutschein', 0],
#  [923, 'zz Freundschaftswerbung', 0],
#  [580, 'zz Fisch', 0],
#  [810, 'zz Küchenmöbel', 0],
#  [320, 'zz Küchenutensilien', 0],
#  [391, 'zz Schneidbretter', 0],
#  [600, 'zz Haushalt', 0],
#  [720, 'zz Grills und Elektrogrills', 0],
#  [380, 'zz Fischküche', 0],
#  [200, 'zz Küchenelektrogeräte', 0],
#  [800, 'zz Möbel & Ambiente', 0],
#  [540, 'zz Pasta&Reis&Hülsenfrüchte', 0],
#  [311, 'zz Töpfe', 0],
#  [210, 'zz Küchenmaschinen', 0],
#  [331, 'zz Messen & Wiegen', 0],
#  [710, 'zz Terrassenmöbel', 0],
#  [530, 'zz Tee & Kaffee & Kakao', 0],
#  [410, 'zz Tischwäsche', 0],
#  [500, 'zz Lebensmittel', 0],
#  [1300, 'Lebensmittel', 6],
#  [240, 'zz Öfen & Grills', 0],
#  [100, 'zz Süßes Backen & Desserts', 0],
#  [730, 'zz Terrassen-& Gartenzubehör', 1],
#  [525, 'zz Grill-Delikatessen', 0],
#  [325, 'zz Kochbücher', 0],
#  [312, 'zz Pfannen', 0],
#  [332, 'zz Warmhalten & Kühlen', 0],
#  [392, 'zz Küchenmesser', 0],
#  [393, 'zz Reiben & Hobeln', 0],
#  [490, 'zz Wärm-&Kühlelektro', 0],
#  [511, 'zz Aroma&Pasten&Fonds', 0],
#  [512, 'zz Essig und Öl', 0],
#  [513, 'zz Getrocknete Gewürze', 0],
#  [521, 'zz Alkoholische Getränke', 0],
#  [522, 'zz Nichtalkoholische Getränke', 0],
#  [551, 'zz Süßwaren', 0],
#  [552, 'zz Desserts', 0],
#  [553, 'zz Backmischungen', 0],
#  [572, 'zz Geflügel', 0],
#  [640, 'zz Haushaltselektro', 0],
#  [1110, 'zz Tischwäsche H&T', 0],
#  [1120, 'zz Bestecke H&T', 0],
#  [1130, 'zz Dekoration Tisch & Tafel', 0],
#  [1140, 'zz Gläser Home & Table', 0],
#  [1150, 'zz Geschirr H&T', 0],
#  [1210, 'zz Plaids und Decken', 0],
#  [1220, 'zz Dekoration Wohnen', 0],
#  [1320, 'zz Elektro-Haushaltsgeräte', 0],
#  [1330, 'zz Nützliche Helfer H&T', 0],
#  [1410, 'zz Kosmetik Bad', 0],
#  [1420, 'zz Badtextil', 0],
#  [1430, 'zz Badeinrichtung', 0],
#  [1440, 'zz nützliche Helfer Bad', 0],
#  [1450, 'zz Bad Elektrogeräte', 0],
#  [1510, 'zz Nachtwäsche', 0],
#  [1230, 'zz Homewear', 0],
#  [1520, 'zz Bettwäsche', 0],
#  [1530, 'zz Dekoration Bett', 0],
#  [1540, 'zz Elektrogeräte Schlafzimmer', 0],
#  [1550, 'zz Kosmetik und Parfum', 0],
#  [1240, 'zz Hausschuhe', 0],
#  [1560, 'zz nützliche Helfer Bett', 0],
#  [1570, 'zz Lampen Schlafzimmer', 0],
#  [1250, 'zz Schuhe Outdoor', 0],
#  [930, 'zz Schnäppchen', 0],
#  [9021, 'zz Geschenkgutschein H&T', 0],
#  [911, 'zz Aktionen-Marketing', 0],
#  [925, 'zz Gutscheine zehn Euro', 0],
#  [926, 'zz FAZ', 0],
#  [940, 'zz Ersatzteile', 0],
#  [595, 'zz Geschenkpakete', 0],
#  [1100, 'Haushalt', 3],
#  [1101, 'Haushaltselektro', 21],
#  [1102, 'Haushaltswaren', 28],
#  [1103, 'Ordnung/Aufbewahren', 71],
#  [1104, 'Reinigen/Säubern/Pflegen', 47],
#  [1105, 'Transportieren', 1],
#  [1200, 'Küche', 1],
#  [1201, 'Backen (Backform/Zubehör)', 92],
#  [1202, 'Kochbücher', 1],
#  [1203, 'Küchenelektrogeräte', 216],
#  [1204, 'Küchengeräte', 33],
#  [1205, 'Küchenmöbel', 14],
#  [1206, 'Küchentextilien', 17],
#  [1207, 'Küchenutensilien', 157],
#  [1208, 'Schneiden/Reiben/Hobeln', 36],
#  [1209, 'Töpfe/Pfannen', 125],
#  [300, 'zz Lebensmittel', 0],
#  [1301, 'Aroma/Fond/Gewürz/Paste/Kräute', 264],
#  [1302, 'Essig/Öl', 54],
#  [1303, 'Fisch/Meeresfrüchte', 38],
#  [1305, 'Kaffee/Kakao/Tee', 21],
#  [1306, 'Käse/Molkereiprodukte', 6],
#  [1307, 'Obst/Gemüse', 27],
#  [1308, 'Pasta/Reis/Hülsenfrüchte/Mehl', 82],
#  [1309, 'Süßwaren/Kuchen/Gebäck', 111],
#  [1310, 'Alkoholische Getränke', 46],
#  [1311, 'Nichtalkoholische Getränke', 8],
#  [400, 'zz Outdoor', 0],
#  [1401, 'Terrassen-/Gartenzubehör', 15],
#  [1402, 'Grills/Öfen/Zubehör', 93],
#  [1500, 'Tisch/Tafel', 9],
#  [1501, 'Besteck', 58],
#  [1502, 'Gläser', 91],
#  [1503, 'Geschirr/Servieren', 215],
#  [1504, 'Tischwäsche', 230],
#  [1600, 'Sonstiges', 1],
#  [1601, 'Dekoration', 30],
#  [1900, 'Marketing', 0],
#  [1901, 'Ersatzteile', 4],
#  [1902, 'FAZ', 0],
#  [1903, 'Freundschaftswerbung', 2],
#  [1904, 'Geschenkgutscheine/-verpackung', 5],
#  [1905, 'zz Gutscheine zehn Euro', 0],
#  [1906, 'zz Kataloge/Beilagen', 0],
#  [1907, 'zz Anleitungen/Etiketten', 1],
#  [1908, 'zz Versandkosten', 0],
#  [1909, 'Monogramm', 0],
#  [2100, 'Tischwäsche JG', 161],
#  [2111, 'Tischdecken JG', 276],
#  [2120, 'Sitz-/Dekokissen JG', 133],
#  [2200, 'Deko/Möbel JG', 1],
#  [2210, 'Deko Wohnzimmer JG', 163],
#  [2220, 'Deko Schlafzimmer JG', 13],
#  [2230, 'Deko Bad JG', 0],
#  [2240, 'Deko Saison JG', 180],
#  [2250, 'Möbel JG', 70],
#  [2260, 'Outdoor Möbel JG', 138],
#  [2270, 'Lampen/Leuchten JG', 96],
#  [2300, 'Wohntextilien JG', 0],
#  [2310, 'Plaids/Decken JG', 36],
#  [2320, 'Vorhänge JG', 2],
#  [2330, 'Teppiche JG', 21],
#  [2400, 'Bekleidung JG', 0],
#  [2411, 'Nachtwäsche Damen JG', 142],
#  [2412, 'Nachtwäsche Herren JG', 0],
#  [2421, 'Sportbekleidung Damen JG', 17],
#  [2422, 'Sportbekleidung Herren JG', 0],
#  [2431, 'Strick Damen JG', 0],
#  [2432, 'Strick Herren JG', 0],
#  [2441, 'Schuhe Damen JG', 7],
#  [2442, 'Schuhe Herren JG', 1],
#  [2450, 'Accessoires JG', 28],
#  [2500, 'Badezimmer JG', 0],
#  [2510, 'Bademäntel JG', 14],
#  [2520, 'Handtücher JG', 34],
#  [2530, 'Badmöbel JG', 8],
#  [2540, 'Kosmetik JG', 55],
#  [2550, 'Badutensilien JG', 30],
#  [2600, 'Schlafzimmer JG', 0],
#  [2610, 'Bettwäsche JG', 250],
#  [2620, 'Tagesdecken JG', 1],
#  [2700, 'Funktion JG', 2],
#  [2710, 'Funktionsbettwäsche JG', 82],
#  [2800, 'Ordnung/Sauberkeit JG', 29],
#  [2810, 'Ordnung/Aufbewahren JG', 33],
#  [2820, 'Elektrogeräte JG', 19],
#  [2830, 'Ordnungsmöbel JG', 3],
#  [2840, 'Reinigen/Säubern/Pflegen JG', 30],
#  [2900, 'Marketing JG', 1],
#  [2901, 'Ersatzteile JG', 0],
#  [2902, 'FAZ JG', 0],
#  [2903, 'Freundschaftswerbung JG', 0],
#  [2904, 'Geschenkgutschein/verpack. JG', 5],
#  [2905, 'zz Gutschein zehn Euro JG', 0],
#  [2906, 'zz Kataloge/Beilagen JG', 0],
#  [2907, 'zz Anleitungen/Etiketten JG', 0],
#  [2908, 'zz Versandkosten JG', 0],
#  [2909, 'Monogramm JG', 1],
#  [1304, 'Fleisch/Wurst', 75],
#  [1910, 'Aktionen/Vertröstung', 0],
#  [1999, 'Alter Kochenartikel', 15],
#  [2999, 'Alter HT Artikel', 0],
#  [1911, 'zz Marketing Adressen', 0],
#  [2911, 'zz Marketing Adressen JG', 0],
#  [9101, 'Adressen Hagen Grote', 0],
#  [9102, 'Gutscheine 10_ Hagen Grote', 0],
#  [9103, 'Kataloge & Beilagen HagenGrote', 0],
#  [9104, 'Anleitungen/Etiketten HG', 208],
#  [9105, 'Versandkosten Hagen Grote', 1],
#  [9201, 'Adressen Julia Grote', 0],
#  [9202, 'Gutschein 10_ Julia Grote', 0],
#  [9203, 'Kataloge &Beilagen Julia Grote', 0],
#  [9204, 'Anleitungen/Etiketten JG', 0],
#  [9205, 'Versandkosten Julia Grote', 0],
#  [2910, 'Aktionen/Vertröstung', 0],
#  [2720, 'Matratzen JG', 0],
#  [2340, 'Kinder JG', 69],
#  [1700, 'Internetartikel', 0],
#  [1701, 'Internet Backen (Formen,...etc', 2],
#  [1702, 'Internet Lebensmittel', 0],
#  [1703, 'Internet Schnäppchen', 0],
#  [2112, 'Tischwäsche Outdoor JG', 29],
#  [2280, 'Deko Garten JG', 67],
#  [1704, 'Internet Küchenhelfer', 0],
#  [1705, 'Internet Grillen Outdoor', 1],
#  [1706, 'Internet Geschirr Servieren', 0],
#  [1707, 'Internet Tischwäsche', 0],
#  [1708, 'Internet Küchentextilien', 1],
#  [1709, 'Internet Reinigen/ Säubern/ Pf', 1],
#  [1710, 'Internet Töpfe und Pfannen', 0],
#  [1312, 'Frischfleisch', 33],
#  [1313, 'Frischfisch', 17],
#  [1314, 'Frischdelikatessen', 3],
#  [1315, 'Frischkäse', 1],
#  [9106, 'VKF GS Newsletter HG', 0],
#  [9107, 'VKF GS sonst. HG', 0],
#  [9206, 'VKF GS Newsletter JG', 0],
#  [9207, 'VKF GS sonst. JG', 0],
#  [1403, 'Elektro Terrasse und Garten', 5],
#  [2290, 'Kränze&Sträuße', 67],
#  [2350, 'Tierbedarf JG', 19],
#  [9111, 'Neukundenkataloge', 0]]

# %%
wg_df = pd.DataFrame(wg_data,columns=['WG_ID','WG_NAME','ITEMS_IN_WG'])
wg_df.to_csv('/Users/maralsheikhzadeh/Documents/Codes/useful-exports/WG_artikels.csv',encoding='utf-8',sep=';',index=False)
